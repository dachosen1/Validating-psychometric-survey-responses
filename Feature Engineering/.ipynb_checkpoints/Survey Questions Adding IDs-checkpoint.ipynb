# %%
import pandas as pd
import os
import pathlib as Path
import numpy as np
import re

# %%
scraped_survey = pd.read_csv('C:/Users/Ergo/Desktop/Git_Dotin/Dotin-Columbia-Castone-Team-Alpha-/Data/Extra/scraped_survey_questions.csv')

# %%
scraped_survey.head()
# Out:
#    Unnamed: 0                    question_type  \
# 0           0                     bf_questions
# 1           1                     bs_questions
# 2           2                    miq_questions
# 3           3  pgi_liking_competence_questions
#
#                                            questions
# 0  ['Untidy', 'Unenvious', 'Efficient', 'Unkind',...
# 1  ['When I go shopping, I buy things that I had ...
# 2  ['I can use lots of different words to express...
# 3  ['Seat patrons at a restaurant', 'Oversee a ho...

# %%
scraped_survey.questions[0]
# Out:
# "['Untidy', 'Unenvious', 'Efficient', 'Unkind', 'Artistic', 'Untalkative', 'Rude', 'Reserved', 'Anxious', 'Warm', 'Moody', 'Envious', 'Untidy', 'Uncreative', 'Intelligent', 'Deep', 'Cooperative', 'Jealous', 'Neat', 'Shy', 'Extraverted', 'Emotional', 'Unworried', 'Quiet', 'Unanxious', 'Organized', 'Inefficient', 'Careless', 'Harsh', 'Emotional', 'Energetic', 'Creative', 'Disorganized', 'Inconsiderate', 'Philosophical', 'Outgoing', 'Kind', 'Systematic', '', '', '', '']"

# %%
df = pd.concat([pd.Series(row['question_type'], row['questions'].split(','))
for _, row in scraped_survey.iterrows()]).reset_index()

df = df.rename(columns={"index": "question", 0: "question_type"})

# %%
df['question'] = df['question'].map(lambda x: x.lstrip("[").rstrip("]"))
df['question'] = df['question'].map(lambda x: x.lstrip("'").rstrip("'"))

# %%
df['question_id'] = 0
c_bs=1
c_miq = 1
c_pgi = 1
for i in range(len(df)):
    if df.loc[i,'question_type'] =='bf_questions':
        df.loc[i,'question_id'] = "bf_"+str(i+1)
    elif df.loc[i,'question_type'] == 'bs_questions':
        df.loc[i,'question_id'] = "bs_"+str(c_bs)
        c_bs+=1
    elif df.loc[i,'question_type'] == 'miq_questions':
        df.loc[i,'question_id'] = "miq_"+str(c_miq)
        c_miq+=1
    elif df.loc[i,'question_type'] == 'pgi_liking_competence_questions':
        df.loc[i,'question_id'] = "pgi_"+str(c_pgi)
        c_pgi+=1
        
df[df['question_type'] == 'bs_questions']
# Out:
#                                              question question_type  \
# 42                                 When I go shopping  bs_questions
# 43   I buy things that I had not intended to purchase  bs_questions
# 44     'When I see something that really interests me  bs_questions
# 45      I buy it without considering the consequences  bs_questions
# 46     'I am greatly attracted by sales and discounts  bs_questions
# 47   'I only buy things that are on discount/sale ...  bs_questions
#
#    question_id
# 42        bs_1
# 43        bs_2
# 44        bs_3
# 45        bs_4
# 46        bs_5
# 47        bs_6

# %%
df['question'].iloc[38] = 'Talkative'
df['question'].iloc[39] = 'Unimaginative'
df['question'].iloc[40] = 'Sympathetic'
df['question'].iloc[41] = 'Intellectual'

# %%
pattern = r'\'.*?'
df['question']=[re.sub(pattern,'', df.question[i]).strip() for i in range(len(df))]

# %%
df
# Out:
#                                       question  \
# 0                                       Untidy
# 1                                    Unenvious
# 2                                    Efficient
# 3                                       Unkind
# 4                                     Artistic
# 5                                  Untalkative
# 6                                         Rude
# 7                                     Reserved
# 8                                      Anxious
# 9                                         Warm
# 10                                       Moody
# 11                                     Envious
# 12                                      Untidy
# 13                                  Uncreative
# 14                                 Intelligent
# 15                                        Deep
# 16                                 Cooperative
# 17                                     Jealous
# 18                                        Neat
# 19                                         Shy
# 20                                 Extraverted
# 21                                   Emotional
# 22                                   Unworried
# 23                                       Quiet
# 24                                   Unanxious
# 25                                   Organized
# 26                                 Inefficient
# 27                                    Careless
# 28                                       Harsh
# 29                                   Emotional
# ..                                         ...
# 136                           Manage an office
# 137          Maintain office financial records
# 138         Manage an electrical power station
# 139              Oversee building construction
# 140                 Write a scientific article
# 141                           Paint a portrait
# 142                      Teach people to dance
# 143             Study the effects of elections
# 144                  Carry and load containers
# 145                     Sell clothes to others
# 146                              Oversee sales
# 147                Keep records of stock sales
# 148       Write computer programs for business
# 149      Inspect construction sites for safety
# 150                              Teach science
# 151                               Write a play
# 152                          Press number four
# 153                       Teach others cooking
# 154                     Set up social programs
# 155                               Drive a taxi
# 156  Escort people through a television studio
# 157                    Organize office records
# 158  Establish a business accounting procedure
# 159                        Analyze survey maps
# 160     Assemble precision optical instruments
# 161                             Study wildlife
# 162                              Draw cartoons
# 163            Supervise children in a nursery
# 164                     Defend people in court
# 165       Smooth wood-furniture with sandpaper
#
#                        question_type question_id
# 0                       bf_questions        bf_1
# 1                       bf_questions        bf_2
# 2                       bf_questions        bf_3
# 3                       bf_questions        bf_4
# 4                       bf_questions        bf_5
# 5                       bf_questions        bf_6
# 6                       bf_questions        bf_7
# 7                       bf_questions        bf_8
# 8                       bf_questions        bf_9
# 9                       bf_questions       bf_10
# 10                      bf_questions       bf_11
# 11                      bf_questions       bf_12
# 12                      bf_questions       bf_13
# 13                      bf_questions       bf_14
# 14                      bf_questions       bf_15
# 15                      bf_questions       bf_16
# 16                      bf_questions       bf_17
# 17                      bf_questions       bf_18
# 18                      bf_questions       bf_19
# 19                      bf_questions       bf_20
# 20                      bf_questions       bf_21
# 21                      bf_questions       bf_22
# 22                      bf_questions       bf_23
# 23                      bf_questions       bf_24
# 24                      bf_questions       bf_25
# 25                      bf_questions       bf_26
# 26                      bf_questions       bf_27
# 27                      bf_questions       bf_28
# 28                      bf_questions       bf_29
# 29                      bf_questions       bf_30
# ..                               ...         ...
# 136  pgi_liking_competence_questions      pgi_13
# 137  pgi_liking_competence_questions      pgi_14
# 138  pgi_liking_competence_questions      pgi_15
# 139  pgi_liking_competence_questions      pgi_16
# 140  pgi_liking_competence_questions      pgi_17
# 141  pgi_liking_competence_questions      pgi_18
# 142  pgi_liking_competence_questions      pgi_19
# 143  pgi_liking_competence_questions      pgi_20
# 144  pgi_liking_competence_questions      pgi_21
# 145  pgi_liking_competence_questions      pgi_22
# 146  pgi_liking_competence_questions      pgi_23
# 147  pgi_liking_competence_questions      pgi_24
# 148  pgi_liking_competence_questions      pgi_25
# 149  pgi_liking_competence_questions      pgi_26
# 150  pgi_liking_competence_questions      pgi_27
# 151  pgi_liking_competence_questions      pgi_28
# 152  pgi_liking_competence_questions      pgi_29
# 153  pgi_liking_competence_questions      pgi_30
# 154  pgi_liking_competence_questions      pgi_31
# 155  pgi_liking_competence_questions      pgi_32
# 156  pgi_liking_competence_questions      pgi_33
# 157  pgi_liking_competence_questions      pgi_34
# 158  pgi_liking_competence_questions      pgi_35
# 159  pgi_liking_competence_questions      pgi_36
# 160  pgi_liking_competence_questions      pgi_37
# 161  pgi_liking_competence_questions      pgi_38
# 162  pgi_liking_competence_questions      pgi_39
# 163  pgi_liking_competence_questions      pgi_40
# 164  pgi_liking_competence_questions      pgi_41
# 165  pgi_liking_competence_questions      pgi_42
#
# [166 rows x 3 columns]

# %%
df.to_csv('C:/Users/Ergo/Desktop/Git_Dotin/Dotin-Columbia-Castone-Team-Alpha-/Data/Extra/survey_questions_with_id_final.csv')
